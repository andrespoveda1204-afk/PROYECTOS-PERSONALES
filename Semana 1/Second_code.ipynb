# %%
## Welcome Message generator

#  Paso 1: Detalles del usuario:
user_name = input("What is your name: ")
hobby = input("What is your favorite hobby: ")

# Paso 2: Generar el mensaje personalizado de bienvenida:
print("\n--- Welcome message ---")
print(f"Hello, {user_name}!!!")
print(f"your favorite hobby is {hobby}." )
# Out:
# What is your name: poveda
# What is your favorite hobby: play soccer
#
# --- Welcome message ---
# Hello, poveda !!!
# your favorite hobby is play soccer

# %%
## Variables y tipos de datos

# Strings
name = "Poveda"
country = "colombia"

# Integer
Age = 18

# Float
height = 9.8

# Boolean
male = True

## imprimir el tipo de dato
print (type (name))
print (type (Age))
print (type (height))
print (type (male))

AGE = "23" ## el 23 es un int, pero esta asignado a la variable AGE como un tipo de dato str

## CONVERSION

edad = int(AGE) ## Aqui convertimos la variable con valor str a int (23) y asi podemos modificar el tipo de dato con los diferentes que existen

print (type(edad))
print ( edad + 2)
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'int'>

# %%
## FORMATOS DE CADENAS F
name = "poveda"
print ("Hello, "+ name + "!!")
print("Hello, {}!!".format(name))
print(f"Hello, {name}!!")
# Out:
# Hello, poveda!!
# Hello, poveda!!
# Hello, poveda

# %%
## PROYECTO DIARIO:
## PEDIR NOMBRE, EDAD Y COLOR FAVORITO Y DAR UN MENSAJE PERSONALIZADO AL USUARIO CON ESTOS DATOS

user_name = input("Hola, Cual es tu nombre: ")
age = int (input(f"{user_name}, cual es tu edad?: "))
color_fav = input(f"{user_name}, cual es tu color favorito?: ")

print("\n--- SALUDO PERSONALIZADO ---\n")
print("Helloo my friend " + user_name + ", welcome to my world\n")
print("You are", age, "years old and your favorite color is " + color_fav)
